# %% [markdown]
# # Stage 7: Model Evaluation & Error Analysis
# ## Industrial Machine Predictive Maintenance
#
# **Objectives:**
# 1. Test the trained `RandomForestClassifier` on the unseen holdout test set (`data/processed/test.csv`).
# 2. Generate classification report (Precision, Recall, F1).
# 3. Inspect Confusion Matrix and prioritize **Fault Recall** over overall accuracy.
# 4. Inspect Feature Importances.
# 5. Analyze engineering tradeoffs between False Negatives and False Positives.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from src.config import PROCESSED_DATA_DIR, PLOTS_DIR, MODEL_FILE, SENSOR_FEATURES, TARGET_COLUMN
from src.evaluate import evaluate_model, print_evaluation_summary

# %% [markdown]
# ### 1. Run Evaluation on Holdout Test Set

# %%
results = evaluate_model(PROCESSED_DATA_DIR / "test.csv")
print_evaluation_summary(results)
